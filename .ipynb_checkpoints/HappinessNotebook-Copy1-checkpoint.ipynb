# %% [markdown]
# # Points that need to be cover in this notebook
# 1. Compare the data with GDP of country
# 2. Compare the data with Polution
# 3. Compare the data with population
# 4. Compare the data with religion
# 5. Compare the data with Average Salary
# 6. Compare the data with weather condition
# 7. Compare the data with gov corruption
# 8. Compare the data with life expetency
# 9. Compare the data with region
# 10. Compare the data with avg age, height, gender

# %% [markdown]
# # Data
# link : https://www.kaggle.com/mathurinache/world-happiness-report

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Data/2015.csv")
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#Lets see how all columns contribute to Hanppines index)
data.plot("Happiness Rank")

#Happines index and Dystopia residual is already expected to decreases with Rank so we ignore them
#Families - Higher the numbe of families, higher the happiness index
#Health - As expected, Health id also a directy priportional to haooinex index
# Out:
# <AxesSubplot:xlabel='Happiness Rank'>

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# # adding GDP

# %% [markdown]
# ### GDP data link : https://data.worldbank.org/indicator/NY.GDP.MKTP.CD?end=2020&most_recent_value_desc=false&start=1960

# %%
GDP = pd.read_csv('data/GDP.csv')

# %%
GDP.rename(columns={"Country Name": "Country"}, inplace = True)

# %%
GDP
# Out:
#                          Country Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
test = pd.merge(data, GDP[['Country','2015']], how='inner', on=['Country'])

# %%
test
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 133  Afghanistan       Southern Asia             153            3.575
# 134       Rwanda  Sub-Saharan Africa             154            3.465
# 135        Benin  Sub-Saharan Africa             155            3.340
# 136      Burundi  Sub-Saharan Africa             157            2.905
# 137         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
# GDP is in millions so we will divide it by million so we get new small scale 
test['2015'] = (test['2015'].astype(float)/1000000)
test
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 133  Afghanistan       Southern Asia             153            3.575
# 134       Rwanda  Sub-Saharan Africa             154            3.465
# 135        Benin  Sub-Saharan Africa             155            3.340
# 136      Burundi  Sub-Saharan Africa             157            2.905
# 137         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
test.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      138.000000       138.000000      138.000000
# mean        77.456522         5.430884        0.047555
# std         46.414055         1.163746        0.017577
# min          1.000000         2.839000        0.018480
# 25%         36.250000         4.553750        0.036610
# 50%         77.000000         5.300000        0.043560
# 75%        117.750000         6.322250        0.050915
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                138.000000  138.000000                138.000000
# mean                   0.851321    0.999543                  0.634178
# std                    0.407429    0.277237                  0.243138
# min                    0.015300    0.000000                  0.000000
# 25%                    0.527197    0.865637                  0.447215
# ...

# %%
test
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 133  Afghanistan       Southern Asia             153            3.575
# 134       Rwanda  Sub-Saharan Africa             154            3.465
# 135        Benin  Sub-Saharan Africa             155            3.340
# 136      Burundi  Sub-Saharan Africa             157            2.905
# 137         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# this will help us see the gdp data in normal format rather than scientific

# %%
test
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 133  Afghanistan       Southern Asia             153            3.575
# 134       Rwanda  Sub-Saharan Africa             154            3.465
# 135        Benin  Sub-Saharan Africa             155            3.340
# 136      Burundi  Sub-Saharan Africa             157            2.905
# 137         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)  Family  \
# 0             0.034                     1.397   1.350
# ...

# %% [markdown]
# # Data for Pollution

# %% [markdown]
# # Data for population

# %%
population = pd.read_csv('data/Population.csv')

# %%
population
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code          1960          1961          1962          1963  \
# 0      SP.POP.TOTL     54208.000     55434.000     56234.000     56699.000
# ...

# %% [markdown]
# # Data of religon

# %% [markdown]
# link : https://datahub.io/sagargg/world-religion-projections#data

# %%
religon = pd.read_csv("Data/Religion.csv")
religon = religon.query("Year == 2020")
religon
# Out:
#      Year                    Region                Country  Buddhists  \
# 241  2020                     World          All Countries      6.600
# 242  2020             North America          All Countries      1.200
# 243  2020   Latin America-Caribbean          All Countries      1.000
# 244  2020                    Europe          All Countries      1.000
# 245  2020  Middle East-North Africa          All Countries      1.000
# ..    ...                       ...                    ...        ...
# 477  2020        Sub-Saharan Africa               Zimbabwe      1.000
# 478  2020        Sub-Saharan Africa            South Sudan      1.000
# 479  2020   Latin America-Caribbean                Curacao      1.000
# 480  2020   Latin America-Caribbean           Sint Maarten      1.000
# 481  2020   Latin America-Caribbean  Caribbean Netherlands      1.000
#
#      Christians  Folk Religions  Hindus  Jews  Muslims  Other Religions  \
# ...

# %%
test2 = pd.merge(data, religon, how='inner', on=['Country'])

# %%
test2
# Out:
#          Country                         Region_x  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 145       Rwanda               Sub-Saharan Africa             154
# 146        Benin               Sub-Saharan Africa             155
# 147        Syria  Middle East and Northern Africa             156
# 148      Burundi               Sub-Saharan Africa             157
# 149         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)  Family  \
# 0              7.587           0.034                     1.397   1.350
# ...

# %% [markdown]
# # income data
# link : https://data.worldbank.org/indicator/NY.ADJ.NNTY.PC.CD

# %%
income = pd.read_csv("Data/salary.csv")
income
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 1    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 2    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 3    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# ...

# %%
income.rename(columns={"Country Name": "Country"}, inplace = True)
test3 = pd.merge(data, income[['Country','2015']], how='inner', on=['Country'])
test3
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 133  Afghanistan       Southern Asia             153            3.575
# 134       Rwanda  Sub-Saharan Africa             154            3.465
# 135        Benin  Sub-Saharan Africa             155            3.340
# 136      Burundi  Sub-Saharan Africa             157            2.905
# 137         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)  Family  \
# 0             0.034                     1.397   1.350
# ...

# %% [markdown]
# # data weather condition

# %% [markdown]
# link : https://www.kaggle.com/akshaychavan/average-temperature-per-country-per-year/data

# %%
avgtemp = pd.read_csv("Data/temp.csv")
avgtemp
# Out:
#             Country   2000   2001   2002   2003   2004   2005   2006   2007  \
# 0             Åland  7.283  6.402  6.801  6.323  6.519  6.724  7.101  7.029
# 1       Afghanistan 15.498 15.778 15.538 14.916 15.771 14.980 15.596 15.106
# 2            Africa 24.588 24.841 24.961 25.026 24.896 25.156 24.819 24.852
# 3           Albania 13.747 13.690 13.560 13.627 13.258 12.747 12.977 13.890
# 4           Algeria 24.032 24.724 24.263 24.394 23.916 24.223 24.201 24.065
# ..              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 239  Western Sahara 23.020 23.705 23.458 23.409 23.421 23.508 23.442 23.145
# 240           Yemen 27.436 27.069 27.125 27.358 27.334 27.295 27.175 27.311
# 241          Zambia 21.559 21.802 22.292 22.157 21.768 22.814 21.784 21.838
# 242        Zimbabwe 21.149 21.694 22.081 21.891 21.331 22.510 21.619 21.604
# 243            year    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#       2008   2009   2010   2011   2012   2013
# ...

# %% [markdown]
# # gov corruption data
# CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high)
# https://data.worldbank.org/indicator/IQ.CPA.TRAN.XQ

# %%
gov = pd.read_csv("Data/gov.csv")
gov
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
# 1    CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
# 2    CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
# 3    CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
# ...

# %% [markdown]
# # life data
# https://data.worldbank.org/indicator/SP.DYN.LE00.IN

# %%
life = pd.read_csv("Data/life.csv")
life
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                               Indicator Name  Indicator Code   1960   1961  \
# 0    Life expectancy at birth, total (years)  SP.DYN.LE00.IN 65.662 66.074
# 1    Life expectancy at birth, total (years)  SP.DYN.LE00.IN 42.716 43.167
# 2    Life expectancy at birth, total (years)  SP.DYN.LE00.IN 32.446 32.962
# 3    Life expectancy at birth, total (years)  SP.DYN.LE00.IN 37.205 37.633
# ...

# %%
avgtemp = pd.read_csv("Data/temp.csv")
avgtemp
# Out:
#             Country   2000   2001   2002   2003   2004   2005   2006   2007  \
# 0             Åland  7.283  6.402  6.801  6.323  6.519  6.724  7.101  7.029
# 1       Afghanistan 15.498 15.778 15.538 14.916 15.771 14.980 15.596 15.106
# 2            Africa 24.588 24.841 24.961 25.026 24.896 25.156 24.819 24.852
# 3           Albania 13.747 13.690 13.560 13.627 13.258 12.747 12.977 13.890
# 4           Algeria 24.032 24.724 24.263 24.394 23.916 24.223 24.201 24.065
# ..              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 239  Western Sahara 23.020 23.705 23.458 23.409 23.421 23.508 23.442 23.145
# 240           Yemen 27.436 27.069 27.125 27.358 27.334 27.295 27.175 27.311
# 241          Zambia 21.559 21.802 22.292 22.157 21.768 22.814 21.784 21.838
# 242        Zimbabwe 21.149 21.694 22.081 21.891 21.331 22.510 21.619 21.604
# 243            year    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#       2008   2009   2010   2011   2012   2013
# ...
